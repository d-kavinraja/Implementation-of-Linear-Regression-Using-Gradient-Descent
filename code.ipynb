# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
student_name="Kavinraja(212222240047)"
data=pd.read_csv("ex1.txt",header=None)
print(data)
plt.scatter(data[0],data[1])
plt.xticks(np.arange(5,30,step=5))
plt.yticks(np.arange(-5,50,step=5))
plt.plot(J_history)
plt.xlabel("Iteration")
plt.ylabel("$J(\Theta)$")
plt.title("Cost function using Gradient Descent")
plt.text(0.1, 0.9, f'Student: {student_name}', transform=plt.gca().transAxes)
# Out:
#           0         1
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\SEC\Downloads\INTRODUCTION TO ML\Implementation-of-Linear-Regression-Using-Gradient-Descent\code.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/SEC/Downloads/INTRODUCTION%20TO%20ML/Implementation-of-Linear-Regression-Using-Gradient-Descent/code.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> plt.xticks(np.arange(5,30,step=5))
#       <a href='vscode-notebook-cell:/c%3A/Users/SEC/Downloads/INTRODUCTION%20TO%20ML/Implementation-of-Linear-Regression-Using-Gradient-Descent/code.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> plt.yticks(np.arange(-5,50,step=5))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/SEC/Downloads/INTRODUCTION%20TO%20ML/Implementation-of-Linear-Regression-Using-Gradient-Descent/code.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> plt.plot(J_history)
#      <a href='vscode-notebook-cell:/c%3A/Users/SEC/Downloads/INTRODUCTION%20TO%20ML/Implementation-of-Linear-Regression-Using-Gradient-Descent/code.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> plt.xlabel("Iteration")
#      <a href='vscode-notebook-cell:/c%3A/Users/SEC/Downloads/INTRODUCTION%20TO%20ML/Implementation-of-Linear-Regression-Using-Gradient-Descent/code.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> plt.ylabel("$J(\Theta)$")
#
# NameError: name 'J_history' is not defined

# %%
# m is theta
def computeCost(x,y,theta):
    m=len(y)
    h=x.dot(theta) # hypothesis
    square_err=(h-y)**2# y is actual value
    return 1/(2*m)  * np.sum(square_err)

# %%
data_n = data.values
m=data_n[:,0].size
x=np.append(np.ones((m,1)),data_n[:,0].reshape(m,1),axis=1)
y=data_n[:,1].reshape(m,1)
theta=np.zeros((2,1))
# Shape
print(x.shape) # Shape
print(y.shape)
print(theta.shape)
# loss Function
computeCost(x,y,theta)
# Out:
# (97, 2)
# (97, 1)
# (2, 1)
# 32.072733877455676

# %%
def gradientDescent(x,y,theta,alpha,num_iters):
  
  m=len(y)
  J_history=[]

  for i in range(num_iters):
    predictions=x.dot(theta)
    error=np.dot(x.transpose(),(predictions - y))
    descent=alpha * 1/m * error
    theta-=descent
    J_history.append(computeCost(x,y,theta))

  return theta, J_history
  
theta,J_history = gradientDescent(x,y,theta,0.01,1500)
print("h(x) ="+str(round(theta[0,0],2))+" + "+str(round(theta[1,0],2))+"x1")
# Out:
# h(x) =-3.63 + 1.17x1

# %%
plt.scatter(data[0],data[1])
x_value=[x for x in range(25)]
y_value=[y*theta[1]+theta[0] for y in x_value]
plt.plot(x_value,y_value,color="yellow")
plt.xticks(np.arange(5,30,step=5))
plt.yticks(np.arange(-5,30,step=5))
plt.xlabel("Polpulation of City (10,000s)")
plt.ylabel("Profit (10,000s)")
plt.title("Profit Prediction")
plt.text(0.1, 0.9, f'Student: {student_name}', transform=plt.gca().transAxes)
# Out:
# Text(0.1, 0.9, 'Student: Kavinraja(212222240047)')

# %%
def predict(x,theta):
  predictions= np.dot(theta.transpose(),x)
  return predictions[0]
  
predict1=predict(np.array([1,3.5]),theta)*10000
print("For population = 35,000, we predict a profit of $"+str(round(predict1,0)))

predict2=predict(np.array([1,7]),theta)*10000
print("For population = 70,000, we predict a profit of $"+str(round(predict2,0)))
# Out:
# For population = 35,000, we predict a profit of $4520.0
# For population = 70,000, we predict a profit of $45342.0
